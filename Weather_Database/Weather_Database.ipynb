# %% [markdown]
# # Deliverable 1. Retrieve Weather Data.
# ---
# 1. Create a folder called `Weather_Database` to save all the files related with this deliverable.
#
# 2. Save the `Weather_Database_starter_code.ipynb` starter code to the `Weather_Database` folder and rename it as `Weather_Database.ipynb`.
#
# 3. Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.
#
# 4. Use the `citipy` module to get the nearest city for each latitude and longitude combination.
#
# 5. Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key; also, it's critical to avoid publishing your API key on your GitHub repository.
#
# 6. Retrieve the following information from the API call:
#
#     * Latitude and longitude
#
#     * Maximum temperature
#
#     * Percent humidity
#
#     * Percent cloudiness
#
#     * Wind speed
#
#     * Weather description (for example, clouds, fog, light rain, clear sky)
#
# 7. Add the weather data to a new DataFrame.
#
# 8. Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.
# ---

# %%
# Import initial libraries
import numpy as np
import pandas as pd
from citipy import citipy

# %% [markdown]
# ## Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.

# %%
# Create a set of random latitude and longitude combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)


# Use the zip function to create an iterator of tuples containing the latitude and longitude combinations
lat_lngs = zip(lats, lngs)

# %%
# Add the latitudes and longitudes to a list
coordinates = list(lat_lngs)

# %% [markdown]
# ## Use the `citipy` module to get the nearest city for each latitude and longitude combination.

# %%
# Create an empty list for holding the cities
cities = []

# Use a for loop to identify nearest city for each latitude and longitude combination using the citipy module
for coordinate in coordinates:
    # Use the citipy module to identify the nearest city to the current coordinate
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 744

# %%
cities
# Out:
# ['qaqortoq',
#  'grytviken',
#  'blackmans bay',
#  'voss',
#  'nadym',
#  'bilibino',
#  'badger',
#  'wailua homesteads',
#  'carbonear',
#  'jayapura',
#  'nabire',
#  'al hazm',
#  'port elizabeth',
#  'bredasdorp',
#  'adamstown',
#  'waitangi',
#  'fort bragg',
#  'new norfolk',
#  'port-aux-francais',
#  'kavaratti',
#  'taiohae',
#  'igarka',
#  'shizunai-furukawacho',
#  'bethel',
#  'kroya',
#  'isafjordur',
#  'corner brook',
#  'saipan',
#  'uturoa',
#  'toga village',
#  'susuman',
#  'luza',
#  'papatowai',
#  'lompoc',
#  'andergrove',
#  'kingston',
#  'georgetown',
#  'mashava',
#  'edinburgh of the seven seas',
#  'akureyri',
#  'albany',
#  'pariaman',
#  'houma',
#  'college',
#  'hamilton',
#  'patacamaya',
#  'port lincoln',
#  'punta arenas',
#  'daru',
#  'enewetak',
#  'hawaiian paradise park',
#  'jinxiang',
#  'batabano',
#  'flying fish cove',
#  'lazaro cardenas',
#  'yebaishou',
#  'olonkinbyen',
#  'sisimiut',
#  'bulgan',
#  'altay',
#  'gemena',
#  "ha'il",
#  'ribeira brava',
#  'maues',
#  'zheleznogorsk',
#  'galesong',
#  'colonia',
#  'ji parana',
#  'asau',
#  'egilsstadir',
#  'freetown',
#  'ishinomaki',
#  'puerto baquerizo moreno',
#  'richards bay',
#  'taoudenni',
#  'ribeira grande',
#  'lages',
#  'jianshui',
#  'aracatuba',
#  'vila velha',
#  'palmer',
#  'ambon',
#  'mar del plata',
#  'lantana',
#  'caninde',
#  'harstad',
#  'port alfred',
#  'puerto natales',
#  'usogorsk',
#  'margaret river',
#  'bayanhongor',
#  'invercargill',
#  'west island',
#  'cabo san lucas',
#  'cherepovets',
#  'atafu village',
#  'hermanus',
#  'avarua',
#  'manavalakurichi',
#  'shenjiamen',
#  'marsh harbour',
#  'vanimo',
#  'north ward',
#  'gizo',
#  'chake chake',
#  'jalai nur',
#  'lebu',
#  'stanley',
#  'porto novo',
#  'thompson',
#  'dano',
#  'yellowknife',
#  'batie',
#  'prince rupert',
#  'polyarnyy',
#  'sungai penuh',
#  'tsiombe',
#  'kruisfontein',
#  'kalemie',
#  'port mathurin',
#  'petropavlovsk-kamchatsky',
#  'bengkulu',
#  'talnakh',
#  'fuvahmulah',
#  'pisco',
#  'anadyr',
#  'sao filipe',
#  'villa del totoral',
#  'xingcheng',
#  'courtenay',
#  'koneurgench',
#  'whitehorse',
#  'conception bay south',
#  'cabedelo',
#  'pearsall',
#  'beruniy',
#  'las lajitas',
#  'sitka',
#  'nuevitas',
#  'ust-nera',
#  'saint-philippe',
#  'aktau',
#  'loreto',
#  'klyuchi',
#  'lae',
#  'portland',
#  'mukalla',
#  "n'dalatando",
#  'ugurludag',
#  'sirte',
#  'miandrivazo',
#  'paradip garh',
#  'gorgan',
#  'hasaki',
#  'ebeltoft',
#  'masterton',
#  'tranovaho',
#  'pancevo',
#  'grand island',
#  'yuzhno-kurilsk',
#  'kataragama',
#  'tucumcari',
#  'tazovsky',
#  'holualoa',
#  'caleta de carquin',
#  'puerto ayora',
#  'vila franca do campo',
#  'kattivakkam',
#  'kone',
#  'afaahiti',
#  'keflavik',
#  'pokhvistnevo',
#  'tazacorte',
#  'la passe',
#  'chonchi',
#  'beledweyne',
#  'takamaka',
#  'vernon',
#  'aral',
#  'iowa falls',
#  'ilulissat',
#  'paragominas',
#  'borcka',
#  'wukari',
#  'devinuwara',
#  'hithadhoo',
#  'valparaiso',
#  'torghay',
#  'ushuaia',
#  'iqaluit',
#  'kodinsk',
#  'lejanias',
#  'quelimane',
#  'novopskov',
#  'tolanaro',
#  'slavyanka',
#  'ugoofaaru',
#  'puerto deseado',
#  'bonthe',
#  'touros',
#  'port augusta',
#  'rikaze',
#  'idri',
#  'snihurivka',
#  'masindi port',
#  'fale old settlement',
#  'katsuren-haebaru',
#  'chernyshevsk',
#  'bakanas',
#  'el limon',
#  'tacambaro de codallos',
#  'nouadhibou',
#  'longyearbyen',
#  'alotau',
#  'papao',
#  'aasiaat',
#  'bedesa',
#  'morki',
#  'vodnyy',
#  'kudat',
#  'brisas barra de suchiate',
#  'le vauclin',
#  'kalabo',
#  'san patricio',
#  'kaga bandoro',
#  'coronel suarez',
#  'coquimbo',
#  'san jose del guaviare',
#  'balakhta',
#  'cranberry township',
#  'deogarh',
#  'nemuro',
#  'kodiak',
#  'punta del este',
#  'nyirbator',
#  'bantogon',
#  'palikir - national government center',
#  'oranjemund',
#  'levuka',
#  "nar'yan-mar",
#  'argostolion',
#  'pandan',
#  'utrik',
#  'beitbridge',
#  'queenstown',
#  'general roca',
#  'sanming',
#  'benguela',
#  'codrington',
#  'callao',
#  "kem'",
#  'howrah',
#  'maceio',
#  'berezhani',
#  'tvoroyri',
#  'lautoka',
#  'puerto escondido',
#  'novovarshavka',
#  'al-`ula',
#  'heyuan',
#  "hayma'",
#  'ahau',
#  'gadzhiyevo',
#  'tura',
#  'praia da vitoria',
#  'alexandria',
#  'grabouw',
#  'tiksi',
#  'khandyga',
#  'gaalkacyo',
#  'dudinka',
#  'sinjai',
#  'port blair',
#  'nantucket',
#  'auki',
#  'nuuk',
#  'haiku-pauwela',
#  'tyukhtet',
#  'saint-joseph',
#  'balkanabat',
#  'vorgashor',
#  'al qusayr',
#  'tralee',
#  'nizao',
#  'ballston spa',
#  'margate',
#  'rio preto da eva',
#  'broome',
#  'harper',
#  'filadelfia',
#  'kalengwa',
#  'hazard',
#  'kapuskasing',
#  'barbacena',
#  'panjab',
#  'kolonia town',
#  'cajaruro',
#  'mount pearl',
#  'zag',
#  'remire-montjoly',
#  'lihue',
#  'sandnessjoen',
#  'san luis de la loma',
#  'la mira',
#  'alvesta',
#  'bathsheba',
#  'laredo',
#  'yarmouth',
#  'los frentones',
#  'kailua-kona',
#  'sheridan',
#  'el granada',
#  'nova sintra',
#  'mount gambier',
#  'daoukro',
#  'villers-cotterets',
#  'hudson',
#  "qal'at bishah",
#  'acarau',
#  'pangody',
#  'san julian',
#  'saint-francois',
#  'sohag',
#  'tanki leendert',
#  'newquay',
#  'alaghsas',
#  'beira',
#  'constantia',
#  'sofifi',
#  'bereznik',
#  'puli',
#  'roma',
#  'laguna',
#  'berezovyy',
#  'oroqen zizhiqi',
#  'crane',
#  'aweil',
#  'korla',
#  'puerto armuelles',
#  'labrador city',
#  'vilhena',
#  'muhos',
#  'vershino-darasunskiy',
#  'tynda',
#  'naze',
#  'east london',
#  'gulf shores',
#  'mawlaik',
#  'sayansk',
#  'la foa',
#  'bandarbeyla',
#  'luderitz',
#  'saratamata',
#  'inari',
#  'quellon',
#  'lubao',
#  'broken hill',
#  'berasia',
#  'lorengau',
#  'at taraf',
#  'mahina',
#  'mabaruma',
#  'kargasok',
#  'rehoboth',
#  'luena',
#  'port sudan',
#  'akrehamn',
#  'newman',
#  'dhidhdhoo',
#  'jincheng',
#  'ad dilam',
#  'beaconsfield',
#  'kathor',
#  'san luis',
#  'malabo',
#  'samana',
#  'tashtyp',
#  'kristiansund',
#  'sorong',
#  'mirnyy',
#  'pendleton',
#  'umm kaddadah',
#  'santyoku',
#  'mermoz boabab',
#  'geraldton',
#  'tabriz',
#  "la'ie",
#  'las palmas de gran canaria',
#  'monrovia',
#  'cockburn town',
#  "st. john's",
#  'dryden',
#  'kidal',
#  'beau vallon',
#  'tobelo',
#  'iskateley',
#  'nicoya',
#  'paracuru',
#  'mentor-on-the-lake',
#  'manicore',
#  'kurumkan',
#  'bay city',
#  'gobabis',
#  'kirakira',
#  'santa luzia',
#  'ormara',
#  'baiyin',
#  'teluk intan',
#  'evanston',
#  'mandera',
#  'makurazaki',
#  'hami',
#  'paka',
#  'mana',
#  'ratnagiri',
#  'kourou',
#  'el alto',
#  'mweka',
#  'korsakov',
#  'kununurra',
#  'postmasburg',
#  'rongelap',
#  'takoradi',
#  'marsaskala',
#  'north bend',
#  'shilin',
#  'trenggalek',
#  'castillos',
#  'ketchikan',
#  'charters towers',
#  'olinda',
#  'capayan',
#  'vilyuchinsk',
#  'shiprock',
#  'sodra sandby',
#  'springbok',
#  'sharanga',
#  'chibougamau',
#  "musay'id",
#  'klaksvik',
#  'xiva',
#  'tabou',
#  'altai',
#  "'ohonua",
#  'shizukuishi',
#  'tobi village',
#  'bikenibeu village',
#  'batamshinskiy',
#  'nampula',
#  'chengde',
#  'syktyvkar',
#  'am djarass',
#  'utete',
#  'luninyets',
#  'plettenberg bay',
#  'ghadamis',
#  'manggar',
#  'juegang',
#  'vadso',
#  'mchinji',
#  'mitu',
#  'dashiqiao',
#  'kirovskiy',
#  'kloulklubed',
#  'carnarvon',
#  'xapuri',
#  'tofol',
#  'saguenay',
#  'kabansk',
#  'kedrovyy',
#  'iquique',
#  'wenchang',
#  'kurmuk',
#  'betio village',
#  'zalingei',
#  'rovaniemi',
#  'hilton head island',
#  'brookings',
#  'kirensk',
#  'isla mujeres',
#  'zapolyarnyy',
#  'jamestown',
#  'acqui terme',
#  'robore',
#  'happy valley-goose bay',
#  'angaur state',
#  'al jawf',
#  'ta`u',
#  'saint-pierre',
#  'an nuhud',
#  'mariental',
#  'gaspe',
#  'mejit',
#  'sao joao da barra',
#  'tougan',
#  'tokar',
#  'santana',
#  'severo-yeniseyskiy',
#  'lata',
#  'mutuali',
#  'turbat',
#  'tak',
#  'balabac',
#  'san antonio de pale',
#  'vingt cinq',
#  'lappeenranta',
#  "al 'alamayn",
#  'manokwari',
#  'wuwei',
#  'athens',
#  'rodez',
#  'batken',
#  'kangding',
#  'jose maria morelos',
#  "kapa'a",
#  'fuente el saz',
#  'kupino',
#  'sao vicente',
#  'puerto leguizamo',
#  'diamantina',
#  'hilo',
#  'marco island',
#  'hastings',
#  'mount isa',
#  'xiaoweizhai',
#  'kayenta',
#  'thabazimbi',
#  "port saint john's",
#  'mahibadhoo',
#  'pechora',
#  'santo antonio do ica',
#  'loen',
#  'hadibu',
#  'weyburn',
#  'poddebice',
#  'markivka',
#  'vallenar',
#  'obo',
#  'moranha',
#  'ancud',
#  'kingscliff',
#  'alo',
#  'vorkuta',
#  'bismarck',
#  'butembo',
#  'sinabang',
#  'coppell',
#  "nuku'alofa",
#  'noumea',
#  'rosarito',
#  "petrovsk-zabaykal'skiy",
#  'youghal',
#  'jiuquan',
#  'chosica',
#  'maridi',
#  'artashat',
#  'kyren',
#  'puerto san carlos',
#  'itaituba',
#  'alice springs',
#  'hovd',
#  'zeya',
#  "al jahra'",
#  "val-d'or",
#  'pontianak',
#  'kondoa',
#  'champoton',
#  'pemba',
#  'carauari',
#  'baoying',
#  'xining',
#  'salinopolis',
#  'arar',
#  'wynyard',
#  'kerikeri',
#  'sikasso',
#  'wewak',
#  'bechar',
#  'gamba',
#  'basna',
#  'scarborough',
#  'rancharia',
#  'gambiran satu',
#  'as samawah',
#  'bereeda',
#  'pachino',
#  'saveni',
#  'bayan nur',
#  'selfoss',
#  'bloemfontein',
#  'raja',
#  'agat village',
#  'tamandare',
#  'helong',
#  'seogwipo',
#  'arno',
#  'basco',
#  'revda',
#  'walvis bay',
#  'shenkursk',
#  'ubari',
#  'sumbawa besar',
#  'kapiri mposhi',
#  'gaigeturi',
#  'kyneton',
#  'shache',
#  'rechka-vydrino',
#  'bukan',
#  'ponta delgada',
#  'okhotsk',
#  'laojunmiao',
#  'island harbour',
#  'surgana',
#  'peel',
#  'quepos',
#  'san andres',
#  'chegdomyn',
#  'uniao da vitoria',
#  'kolonia',
#  'carutapera',
#  'chemolgan',
#  'imbituba',
#  'jinchang',
#  'port hedland',
#  'taltal',
#  'isiro',
#  'ba',
#  'erriadh',
#  'coahuayana de hidalgo',
#  'quatre cocos',
#  'neiafu',
#  'ibotirama',
#  'gaillard',
#  'belyy yar',
#  'laikit, laikit ii (dimembe)',
#  'udachny',
#  'shama junction',
#  'fisterra',
#  'arraial do cabo',
#  'acapulco de juarez',
#  'sao raimundo das mangabeiras',
#  'al kharj',
#  'smidovich',
#  'novofedorivka',
#  'san rafael',
#  'lerwick',
#  'mossel bay',
#  'laihia',
#  'undurkhaan',
#  'kananga',
#  'sabha',
#  'ciudad melchor muzquiz',
#  'dom pedrito',
#  'fort st. john',
#  'madanapalle',
#  'qamdo',
#  'northam',
#  'ridder',
#  'tumbes',
#  'ekibastuz',
#  'guerrero negro',
#  'inhambane',
#  'solwezi',
#  'kasongo-lunda',
#  'vuktyl',
#  'champerico',
#  'mtwara',
#  'launceston',
#  'livadiya',
#  'jerantut',
#  'vila do maio',
#  'gallipoli',
#  'sainte-anne-de-bellevue',
#  'palmaner',
#  'bulawayo',
#  'colares',
#  'weno',
#  'foumbot',
#  'duayaw-nkwanta',
#  'sassandra',
#  'heroica caborca',
#  'kilindoni',
#  'shingu',
#  'hukumati azrah',
#  'kalmunai',
#  'bhimunipatnam',
#  'great falls',
#  'mili',
#  'anacapri',
#  'elliot',
#  'winejok',
#  'cloverdale',
#  'iquitos',
#  'surgut',
#  'lethem',
#  'kaffrine',
#  'saudarkrokur',
#  'fortuna',
#  'cherkessk',
#  'strezhevoy',
#  'salahonda',
#  'isle of bute',
#  'mlowo',
#  'ulsteinvik',
#  'tabarka',
#  "mil'kovo",
#  'floriano',
#  'puerto lempira',
#  'oppdal',
#  'shalqar',
#  'arboga',
#  'eraan',
#  'tra mhor',
#  'saint john',
#  'anse la raye',
#  'nur-sultan',
#  'praya',
#  'sabzevar',
#  'emerald',
#  'serdar',
#  'minot air force base',
#  'kupang',
#  'nagato',
#  'las palmas',
#  'ouadda',
#  'pasighat',
#  'pauini',
#  'salalah',
#  'ruelle-sur-touvre',
#  'okha',
#  'ebon',
#  'sonqor',
#  'diu',
#  'lundazi',
#  'bowen',
#  'palo santo',
#  'hoxtolgay',
#  'nema',
#  'sur',
#  'nova vicosa',
#  'xilin hot',
#  'mary',
#  'kenora',
#  'mamuju']

# %% [markdown]
# ## Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key.

# %%
# Import the requests library
import requests

# Import the time library
import time

# Import the datetime module from the datetime library
from datetime import datetime

# Import the OpenWeatherMap's API key
from config import weather_api_key

# %%
# Assemble the OpenWeatherMap's API call
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
#print(url)

# %%
test_url = url + "&q=" + "voss"
testcity_weather = requests.get(test_url)
testcity_weather.json()
# Out:
# {'coord': {'lon': 6.4229, 'lat': 60.623},
#  'weather': [{'id': 804,
#    'main': 'Clouds',
#    'description': 'overcast clouds',
#    'icon': '04n'}],
#  'base': 'stations',
#  'main': {'temp': 46.54,
#   'feels_like': 43,
#   'temp_min': 46.54,
#   'temp_max': 46.54,
#   'pressure': 1018,
#   'humidity': 99,
#   'sea_level': 1018,
#   'grnd_level': 1011},
#  'visibility': 25,
#  'wind': {'speed': 7.07, 'deg': 237, 'gust': 9.64},
#  'clouds': {'all': 100},
#  'dt': 1685233811,
#  'sys': {'type': 2,
#   'id': 2006814,
#   'country': 'NO',
#   'sunrise': 1685240686,
#   'sunset': 1685306318},
#  'timezone': 7200,
#  'id': 3131329,
#  'name': 'Voss',
#  'cod': 200}

# %% [markdown]
# ## Retrieve the following information from the API call.
#
# - The latitude and longitude
# - The Max temperature
# - The % humidity
# - The % cloudiness
# - The Wind speed
# - The Weather description, i.e., cloudy, fog, light rain, clear sky, etc.

# %%
# Create an empty list to hold weather data for each city
city_data = []

# Print a message to indicate that the data retrieval starts
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters and set them to 1
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data for each city
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create an endpoint URL for each city
    city_url = url + "&q=" + city.replace(" ","+")
    
    # Log the url, record, and set numbers
    print(f"Processing Record {record_count} of Set {set_count} | {city}")

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        city_weather = requests.get(city_url).json()
      # Parse out the latitude, longitude, max temp, humidity, cloudiness, wind, country, and weather description
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_desc = city_weather["weather"][0]["description"]     
            
        # Append the city information into the city_data list
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Desc": city_desc
                          })
    
    
    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass

# Indicate that the data retrieval is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | qaqortoq
# Processing Record 2 of Set 1 | grytviken
# Processing Record 3 of Set 1 | blackmans bay
# Processing Record 4 of Set 1 | voss
# Processing Record 5 of Set 1 | nadym
# Processing Record 6 of Set 1 | bilibino
# Processing Record 7 of Set 1 | badger
# Processing Record 8 of Set 1 | wailua homesteads
# Processing Record 9 of Set 1 | carbonear
# Processing Record 10 of Set 1 | jayapura
# Processing Record 11 of Set 1 | nabire
# Processing Record 12 of Set 1 | al hazm
# Processing Record 13 of Set 1 | port elizabeth
# Processing Record 14 of Set 1 | bredasdorp
# Processing Record 15 of Set 1 | adamstown
# Processing Record 16 of Set 1 | waitangi
# Processing Record 17 of Set 1 | fort bragg
# Processing Record 18 of Set 1 | new norfolk
# Processing Record 19 of Set 1 | port-aux-francais
# Processing Record 20 of Set 1 | kavaratti
# Processing Record 21 of Set 1 | taiohae
# City not found. Skipping...
# Processing Record 22 of Set 1 | igarka
# Processing Record 23 of Set 1 | shizunai-furukawacho
# Processing Record 24 of Set 1 | bethel
# Processing Record 25 of Set 1 | kroya
# Processing Record 26 of Set 1 | isafjordur
# Processing Record 27 of Set 1 | corner brook
# Processing Record 28 of Set 1 | saipan
# Processing Record 29 of Set 1 | uturoa
# Processing Record 30 of Set 1 | toga village
# City not found. Skipping...
# Processing Record 31 of Set 1 | susuman
# Processing Record 32 of Set 1 | luza
# Processing Record 33 of Set 1 | papatowai
# Processing Record 34 of Set 1 | lompoc
# Processing Record 35 of Set 1 | andergrove
# Processing Record 36 of Set 1 | kingston
# Processing Record 37 of Set 1 | georgetown
# Processing Record 38 of Set 1 | mashava
# Processing Record 39 of Set 1 | edinburgh of the seven seas
# Processing Record 40 of Set 1 | akureyri
# Processing Record 41 of Set 1 | albany
# Processing Record 42 of Set 1 | pariaman
# Processing Record 43 of Set 1 | houma
# Processing Record 44 of Set 1 | college
# Processing Record 45 of Set 1 | hamilton
# Processing Record 46 of Set 1 | patacamaya
# Processing Record 47 of Set 1 | port lincoln
# Processing Record 48 of Set 1 | punta arenas
# Processing Record 49 of Set 1 | daru
# Processing Record 50 of Set 1 | enewetak
# Processing Record 1 of Set 2 | hawaiian paradise park
# Processing Record 2 of Set 2 | jinxiang
# Processing Record 3 of Set 2 | batabano
# Processing Record 4 of Set 2 | flying fish cove
# Processing Record 5 of Set 2 | lazaro cardenas
# Processing Record 6 of Set 2 | yebaishou
# Processing Record 7 of Set 2 | olonkinbyen
# Processing Record 8 of Set 2 | sisimiut
# Processing Record 9 of Set 2 | bulgan
# Processing Record 10 of Set 2 | altay
# Processing Record 11 of Set 2 | gemena
# Processing Record 12 of Set 2 | ha'il
# Processing Record 13 of Set 2 | ribeira brava
# Processing Record 14 of Set 2 | maues
# Processing Record 15 of Set 2 | zheleznogorsk
# Processing Record 16 of Set 2 | galesong
# Processing Record 17 of Set 2 | colonia
# Processing Record 18 of Set 2 | ji parana
# City not found. Skipping...
# Processing Record 19 of Set 2 | asau
# Processing Record 20 of Set 2 | egilsstadir
# Processing Record 21 of Set 2 | freetown
# Processing Record 22 of Set 2 | ishinomaki
# Processing Record 23 of Set 2 | puerto baquerizo moreno
# Processing Record 24 of Set 2 | richards bay
# Processing Record 25 of Set 2 | taoudenni
# Processing Record 26 of Set 2 | ribeira grande
# Processing Record 27 of Set 2 | lages
# Processing Record 28 of Set 2 | jianshui
# Processing Record 29 of Set 2 | aracatuba
# Processing Record 30 of Set 2 | vila velha
# Processing Record 31 of Set 2 | palmer
# Processing Record 32 of Set 2 | ambon
# Processing Record 33 of Set 2 | mar del plata
# Processing Record 34 of Set 2 | lantana
# Processing Record 35 of Set 2 | caninde
# Processing Record 36 of Set 2 | harstad
# Processing Record 37 of Set 2 | port alfred
# Processing Record 38 of Set 2 | puerto natales
# Processing Record 39 of Set 2 | usogorsk
# Processing Record 40 of Set 2 | margaret river
# Processing Record 41 of Set 2 | bayanhongor
# Processing Record 42 of Set 2 | invercargill
# Processing Record 43 of Set 2 | west island
# Processing Record 44 of Set 2 | cabo san lucas
# Processing Record 45 of Set 2 | cherepovets
# Processing Record 46 of Set 2 | atafu village
# Processing Record 47 of Set 2 | hermanus
# Processing Record 48 of Set 2 | avarua
# Processing Record 49 of Set 2 | manavalakurichi
# Processing Record 50 of Set 2 | shenjiamen
# Processing Record 1 of Set 3 | marsh harbour
# Processing Record 2 of Set 3 | vanimo
# Processing Record 3 of Set 3 | north ward
# Processing Record 4 of Set 3 | gizo
# Processing Record 5 of Set 3 | chake chake
# Processing Record 6 of Set 3 | jalai nur
# Processing Record 7 of Set 3 | lebu
# Processing Record 8 of Set 3 | stanley
# Processing Record 9 of Set 3 | porto novo
# Processing Record 10 of Set 3 | thompson
# Processing Record 11 of Set 3 | dano
# Processing Record 12 of Set 3 | yellowknife
# Processing Record 13 of Set 3 | batie
# Processing Record 14 of Set 3 | prince rupert
# Processing Record 15 of Set 3 | polyarnyy
# Processing Record 16 of Set 3 | sungai penuh
# Processing Record 17 of Set 3 | tsiombe
# Processing Record 18 of Set 3 | kruisfontein
# Processing Record 19 of Set 3 | kalemie
# Processing Record 20 of Set 3 | port mathurin
# Processing Record 21 of Set 3 | petropavlovsk-kamchatsky
# Processing Record 22 of Set 3 | bengkulu
# Processing Record 23 of Set 3 | talnakh
# Processing Record 24 of Set 3 | fuvahmulah
# City not found. Skipping...
# Processing Record 25 of Set 3 | pisco
# Processing Record 26 of Set 3 | anadyr
# Processing Record 27 of Set 3 | sao filipe
# Processing Record 28 of Set 3 | villa del totoral
# Processing Record 29 of Set 3 | xingcheng
# Processing Record 30 of Set 3 | courtenay
# Processing Record 31 of Set 3 | koneurgench
# City not found. Skipping...
# Processing Record 32 of Set 3 | whitehorse
# Processing Record 33 of Set 3 | conception bay south
# Processing Record 34 of Set 3 | cabedelo
# Processing Record 35 of Set 3 | pearsall
# Processing Record 36 of Set 3 | beruniy
# Processing Record 37 of Set 3 | las lajitas
# Processing Record 38 of Set 3 | sitka
# Processing Record 39 of Set 3 | nuevitas
# Processing Record 40 of Set 3 | ust-nera
# Processing Record 41 of Set 3 | saint-philippe
# Processing Record 42 of Set 3 | aktau
# Processing Record 43 of Set 3 | loreto
# Processing Record 44 of Set 3 | klyuchi
# Processing Record 45 of Set 3 | lae
# Processing Record 46 of Set 3 | portland
# Processing Record 47 of Set 3 | mukalla
# Processing Record 48 of Set 3 | n'dalatando
# Processing Record 49 of Set 3 | ugurludag
# Processing Record 50 of Set 3 | sirte
# Processing Record 1 of Set 4 | miandrivazo
# Processing Record 2 of Set 4 | paradip garh
# Processing Record 3 of Set 4 | gorgan
# Processing Record 4 of Set 4 | hasaki
# Processing Record 5 of Set 4 | ebeltoft
# Processing Record 6 of Set 4 | masterton
# Processing Record 7 of Set 4 | tranovaho
# City not found. Skipping...
# Processing Record 8 of Set 4 | pancevo
# Processing Record 9 of Set 4 | grand island
# Processing Record 10 of Set 4 | yuzhno-kurilsk
# Processing Record 11 of Set 4 | kataragama
# City not found. Skipping...
# Processing Record 12 of Set 4 | tucumcari
# Processing Record 13 of Set 4 | tazovsky
# Processing Record 14 of Set 4 | holualoa
# Processing Record 15 of Set 4 | caleta de carquin
# Processing Record 16 of Set 4 | puerto ayora
# Processing Record 17 of Set 4 | vila franca do campo
# Processing Record 18 of Set 4 | kattivakkam
# Processing Record 19 of Set 4 | kone
# Processing Record 20 of Set 4 | afaahiti
# Processing Record 21 of Set 4 | keflavik
# Processing Record 22 of Set 4 | pokhvistnevo
# Processing Record 23 of Set 4 | tazacorte
# Processing Record 24 of Set 4 | la passe
# Processing Record 25 of Set 4 | chonchi
# Processing Record 26 of Set 4 | beledweyne
# Processing Record 27 of Set 4 | takamaka
# City not found. Skipping...
# Processing Record 28 of Set 4 | vernon
# Processing Record 29 of Set 4 | aral
# Processing Record 30 of Set 4 | iowa falls
# Processing Record 31 of Set 4 | ilulissat
# Processing Record 32 of Set 4 | paragominas
# Processing Record 33 of Set 4 | borcka
# Processing Record 34 of Set 4 | wukari
# Processing Record 35 of Set 4 | devinuwara
# City not found. Skipping...
# Processing Record 36 of Set 4 | hithadhoo
# Processing Record 37 of Set 4 | valparaiso
# Processing Record 38 of Set 4 | torghay
# Processing Record 39 of Set 4 | ushuaia
# Processing Record 40 of Set 4 | iqaluit
# Processing Record 41 of Set 4 | kodinsk
# Processing Record 42 of Set 4 | lejanias
# Processing Record 43 of Set 4 | quelimane
# Processing Record 44 of Set 4 | novopskov
# Processing Record 45 of Set 4 | tolanaro
# Processing Record 46 of Set 4 | slavyanka
# Processing Record 47 of Set 4 | ugoofaaru
# Processing Record 48 of Set 4 | puerto deseado
# Processing Record 49 of Set 4 | bonthe
# Processing Record 50 of Set 4 | touros
# Processing Record 1 of Set 5 | port augusta
# Processing Record 2 of Set 5 | rikaze
# Processing Record 3 of Set 5 | idri
# Processing Record 4 of Set 5 | snihurivka
# Processing Record 5 of Set 5 | masindi port
# Processing Record 6 of Set 5 | fale old settlement
# Processing Record 7 of Set 5 | katsuren-haebaru
# Processing Record 8 of Set 5 | chernyshevsk
# Processing Record 9 of Set 5 | bakanas
# Processing Record 10 of Set 5 | el limon
# Processing Record 11 of Set 5 | tacambaro de codallos
# Processing Record 12 of Set 5 | nouadhibou
# Processing Record 13 of Set 5 | longyearbyen
# Processing Record 14 of Set 5 | alotau
# City not found. Skipping...
# Processing Record 15 of Set 5 | papao
# Processing Record 16 of Set 5 | aasiaat
# Processing Record 17 of Set 5 | bedesa
# Processing Record 18 of Set 5 | morki
# Processing Record 19 of Set 5 | vodnyy
# Processing Record 20 of Set 5 | kudat
# Processing Record 21 of Set 5 | brisas barra de suchiate
# Processing Record 22 of Set 5 | le vauclin
# Processing Record 23 of Set 5 | kalabo
# Processing Record 24 of Set 5 | san patricio
# Processing Record 25 of Set 5 | kaga bandoro
# Processing Record 26 of Set 5 | coronel suarez
# Processing Record 27 of Set 5 | coquimbo
# Processing Record 28 of Set 5 | san jose del guaviare
# Processing Record 29 of Set 5 | balakhta
# Processing Record 30 of Set 5 | cranberry township
# City not found. Skipping...
# Processing Record 31 of Set 5 | deogarh
# Processing Record 32 of Set 5 | nemuro
# Processing Record 33 of Set 5 | kodiak
# Processing Record 34 of Set 5 | punta del este
# Processing Record 35 of Set 5 | nyirbator
# Processing Record 36 of Set 5 | bantogon
# Processing Record 37 of Set 5 | palikir - national government center
# Processing Record 38 of Set 5 | oranjemund
# Processing Record 39 of Set 5 | levuka
# Processing Record 40 of Set 5 | nar'yan-mar
# Processing Record 41 of Set 5 | argostolion
# Processing Record 42 of Set 5 | pandan
# Processing Record 43 of Set 5 | utrik
# Processing Record 44 of Set 5 | beitbridge
# Processing Record 45 of Set 5 | queenstown
# Processing Record 46 of Set 5 | general roca
# Processing Record 47 of Set 5 | sanming
# Processing Record 48 of Set 5 | benguela
# Processing Record 49 of Set 5 | codrington
# Processing Record 50 of Set 5 | callao
# Processing Record 1 of Set 6 | kem'
# Processing Record 2 of Set 6 | howrah
# Processing Record 3 of Set 6 | maceio
# Processing Record 4 of Set 6 | berezhani
# Processing Record 5 of Set 6 | tvoroyri
# Processing Record 6 of Set 6 | lautoka
# Processing Record 7 of Set 6 | puerto escondido
# Processing Record 8 of Set 6 | novovarshavka
# Processing Record 9 of Set 6 | al-`ula
# City not found. Skipping...
# Processing Record 10 of Set 6 | heyuan
# Processing Record 11 of Set 6 | hayma'
# City not found. Skipping...
# Processing Record 12 of Set 6 | ahau
# City not found. Skipping...
# Processing Record 13 of Set 6 | gadzhiyevo
# Processing Record 14 of Set 6 | tura
# Processing Record 15 of Set 6 | praia da vitoria
# Processing Record 16 of Set 6 | alexandria
# Processing Record 17 of Set 6 | grabouw
# Processing Record 18 of Set 6 | tiksi
# Processing Record 19 of Set 6 | khandyga
# Processing Record 20 of Set 6 | gaalkacyo
# Processing Record 21 of Set 6 | dudinka
# Processing Record 22 of Set 6 | sinjai
# Processing Record 23 of Set 6 | port blair
# Processing Record 24 of Set 6 | nantucket
# Processing Record 25 of Set 6 | auki
# Processing Record 26 of Set 6 | nuuk
# Processing Record 27 of Set 6 | haiku-pauwela
# Processing Record 28 of Set 6 | tyukhtet
# Processing Record 29 of Set 6 | saint-joseph
# Processing Record 30 of Set 6 | balkanabat
# Processing Record 31 of Set 6 | vorgashor
# Processing Record 32 of Set 6 | al qusayr
# Processing Record 33 of Set 6 | tralee
# Processing Record 34 of Set 6 | nizao
# Processing Record 35 of Set 6 | ballston spa
# Processing Record 36 of Set 6 | margate
# Processing Record 37 of Set 6 | rio preto da eva
# Processing Record 38 of Set 6 | broome
# Processing Record 39 of Set 6 | harper
# Processing Record 40 of Set 6 | filadelfia
# Processing Record 41 of Set 6 | kalengwa
# Processing Record 42 of Set 6 | hazard
# Processing Record 43 of Set 6 | kapuskasing
# Processing Record 44 of Set 6 | barbacena
# Processing Record 45 of Set 6 | panjab
# Processing Record 46 of Set 6 | kolonia town
# Processing Record 47 of Set 6 | cajaruro
# Processing Record 48 of Set 6 | mount pearl
# Processing Record 49 of Set 6 | zag
# Processing Record 50 of Set 6 | remire-montjoly
# Processing Record 1 of Set 7 | lihue
# Processing Record 2 of Set 7 | sandnessjoen
# Processing Record 3 of Set 7 | san luis de la loma
# Processing Record 4 of Set 7 | la mira
# Processing Record 5 of Set 7 | alvesta
# Processing Record 6 of Set 7 | bathsheba
# Processing Record 7 of Set 7 | laredo
# Processing Record 8 of Set 7 | yarmouth
# Processing Record 9 of Set 7 | los frentones
# Processing Record 10 of Set 7 | kailua-kona
# Processing Record 11 of Set 7 | sheridan
# Processing Record 12 of Set 7 | el granada
# Processing Record 13 of Set 7 | nova sintra
# Processing Record 14 of Set 7 | mount gambier
# Processing Record 15 of Set 7 | daoukro
# Processing Record 16 of Set 7 | villers-cotterets
# Processing Record 17 of Set 7 | hudson
# Processing Record 18 of Set 7 | qal'at bishah
# City not found. Skipping...
# Processing Record 19 of Set 7 | acarau
# Processing Record 20 of Set 7 | pangody
# Processing Record 21 of Set 7 | san julian
# Processing Record 22 of Set 7 | saint-francois
# Processing Record 23 of Set 7 | sohag
# Processing Record 24 of Set 7 | tanki leendert
# City not found. Skipping...
# Processing Record 25 of Set 7 | newquay
# Processing Record 26 of Set 7 | alaghsas
# Processing Record 27 of Set 7 | beira
# Processing Record 28 of Set 7 | constantia
# Processing Record 29 of Set 7 | sofifi
# City not found. Skipping...
# Processing Record 30 of Set 7 | bereznik
# Processing Record 31 of Set 7 | puli
# Processing Record 32 of Set 7 | roma
# Processing Record 33 of Set 7 | laguna
# Processing Record 34 of Set 7 | berezovyy
# Processing Record 35 of Set 7 | oroqen zizhiqi
# Processing Record 36 of Set 7 | crane
# Processing Record 37 of Set 7 | aweil
# Processing Record 38 of Set 7 | korla
# Processing Record 39 of Set 7 | puerto armuelles
# Processing Record 40 of Set 7 | labrador city
# Processing Record 41 of Set 7 | vilhena
# Processing Record 42 of Set 7 | muhos
# Processing Record 43 of Set 7 | vershino-darasunskiy
# Processing Record 44 of Set 7 | tynda
# Processing Record 45 of Set 7 | naze
# Processing Record 46 of Set 7 | east london
# Processing Record 47 of Set 7 | gulf shores
# Processing Record 48 of Set 7 | mawlaik
# Processing Record 49 of Set 7 | sayansk
# Processing Record 50 of Set 7 | la foa
# Processing Record 1 of Set 8 | bandarbeyla
# Processing Record 2 of Set 8 | luderitz
# Processing Record 3 of Set 8 | saratamata
# City not found. Skipping...
# Processing Record 4 of Set 8 | inari
# Processing Record 5 of Set 8 | quellon
# Processing Record 6 of Set 8 | lubao
# Processing Record 7 of Set 8 | broken hill
# Processing Record 8 of Set 8 | berasia
# Processing Record 9 of Set 8 | lorengau
# Processing Record 10 of Set 8 | at taraf
# Processing Record 11 of Set 8 | mahina
# Processing Record 12 of Set 8 | mabaruma
# Processing Record 13 of Set 8 | kargasok
# Processing Record 14 of Set 8 | rehoboth
# Processing Record 15 of Set 8 | luena
# Processing Record 16 of Set 8 | port sudan
# Processing Record 17 of Set 8 | akrehamn
# Processing Record 18 of Set 8 | newman
# Processing Record 19 of Set 8 | dhidhdhoo
# Processing Record 20 of Set 8 | jincheng
# Processing Record 21 of Set 8 | ad dilam
# Processing Record 22 of Set 8 | beaconsfield
# Processing Record 23 of Set 8 | kathor
# Processing Record 24 of Set 8 | san luis
# Processing Record 25 of Set 8 | malabo
# Processing Record 26 of Set 8 | samana
# Processing Record 27 of Set 8 | tashtyp
# Processing Record 28 of Set 8 | kristiansund
# Processing Record 29 of Set 8 | sorong
# Processing Record 30 of Set 8 | mirnyy
# Processing Record 31 of Set 8 | pendleton
# Processing Record 32 of Set 8 | umm kaddadah
# Processing Record 33 of Set 8 | santyoku
# Processing Record 34 of Set 8 | mermoz boabab
# Processing Record 35 of Set 8 | geraldton
# Processing Record 36 of Set 8 | tabriz
# Processing Record 37 of Set 8 | la'ie
# Processing Record 38 of Set 8 | las palmas de gran canaria
# Processing Record 39 of Set 8 | monrovia
# Processing Record 40 of Set 8 | cockburn town
# Processing Record 41 of Set 8 | st. john's
# Processing Record 42 of Set 8 | dryden
# Processing Record 43 of Set 8 | kidal
# Processing Record 44 of Set 8 | beau vallon
# Processing Record 45 of Set 8 | tobelo
# Processing Record 46 of Set 8 | iskateley
# Processing Record 47 of Set 8 | nicoya
# Processing Record 48 of Set 8 | paracuru
# Processing Record 49 of Set 8 | mentor-on-the-lake
# Processing Record 50 of Set 8 | manicore
# Processing Record 1 of Set 9 | kurumkan
# Processing Record 2 of Set 9 | bay city
# Processing Record 3 of Set 9 | gobabis
# Processing Record 4 of Set 9 | kirakira
# Processing Record 5 of Set 9 | santa luzia
# Processing Record 6 of Set 9 | ormara
# Processing Record 7 of Set 9 | baiyin
# Processing Record 8 of Set 9 | teluk intan
# Processing Record 9 of Set 9 | evanston
# Processing Record 10 of Set 9 | mandera
# Processing Record 11 of Set 9 | makurazaki
# Processing Record 12 of Set 9 | hami
# Processing Record 13 of Set 9 | paka
# Processing Record 14 of Set 9 | mana
# Processing Record 15 of Set 9 | ratnagiri
# Processing Record 16 of Set 9 | kourou
# Processing Record 17 of Set 9 | el alto
# Processing Record 18 of Set 9 | mweka
# Processing Record 19 of Set 9 | korsakov
# Processing Record 20 of Set 9 | kununurra
# Processing Record 21 of Set 9 | postmasburg
# City not found. Skipping...
# Processing Record 22 of Set 9 | rongelap
# Processing Record 23 of Set 9 | takoradi
# Processing Record 24 of Set 9 | marsaskala
# City not found. Skipping...
# Processing Record 25 of Set 9 | north bend
# Processing Record 26 of Set 9 | shilin
# Processing Record 27 of Set 9 | trenggalek
# Processing Record 28 of Set 9 | castillos
# Processing Record 29 of Set 9 | ketchikan
# Processing Record 30 of Set 9 | charters towers
# Processing Record 31 of Set 9 | olinda
# Processing Record 32 of Set 9 | capayan
# Processing Record 33 of Set 9 | vilyuchinsk
# Processing Record 34 of Set 9 | shiprock
# Processing Record 35 of Set 9 | sodra sandby
# Processing Record 36 of Set 9 | springbok
# Processing Record 37 of Set 9 | sharanga
# Processing Record 38 of Set 9 | chibougamau
# Processing Record 39 of Set 9 | musay'id
# City not found. Skipping...
# Processing Record 40 of Set 9 | klaksvik
# Processing Record 41 of Set 9 | xiva
# Processing Record 42 of Set 9 | tabou
# Processing Record 43 of Set 9 | altai
# Processing Record 44 of Set 9 | 'ohonua
# City not found. Skipping...
# Processing Record 45 of Set 9 | shizukuishi
# Processing Record 46 of Set 9 | tobi village
# City not found. Skipping...
# Processing Record 47 of Set 9 | bikenibeu village
# Processing Record 48 of Set 9 | batamshinskiy
# Processing Record 49 of Set 9 | nampula
# Processing Record 50 of Set 9 | chengde
# Processing Record 1 of Set 10 | syktyvkar
# Processing Record 2 of Set 10 | am djarass
# City not found. Skipping...
# Processing Record 3 of Set 10 | utete
# Processing Record 4 of Set 10 | luninyets
# Processing Record 5 of Set 10 | plettenberg bay
# Processing Record 6 of Set 10 | ghadamis
# Processing Record 7 of Set 10 | manggar
# Processing Record 8 of Set 10 | juegang
# Processing Record 9 of Set 10 | vadso
# Processing Record 10 of Set 10 | mchinji
# Processing Record 11 of Set 10 | mitu
# Processing Record 12 of Set 10 | dashiqiao
# Processing Record 13 of Set 10 | kirovskiy
# Processing Record 14 of Set 10 | kloulklubed
# Processing Record 15 of Set 10 | carnarvon
# Processing Record 16 of Set 10 | xapuri
# Processing Record 17 of Set 10 | tofol
# Processing Record 18 of Set 10 | saguenay
# Processing Record 19 of Set 10 | kabansk
# Processing Record 20 of Set 10 | kedrovyy
# Processing Record 21 of Set 10 | iquique
# Processing Record 22 of Set 10 | wenchang
# Processing Record 23 of Set 10 | kurmuk
# Processing Record 24 of Set 10 | betio village
# Processing Record 25 of Set 10 | zalingei
# Processing Record 26 of Set 10 | rovaniemi
# Processing Record 27 of Set 10 | hilton head island
# Processing Record 28 of Set 10 | brookings
# Processing Record 29 of Set 10 | kirensk
# Processing Record 30 of Set 10 | isla mujeres
# Processing Record 31 of Set 10 | zapolyarnyy
# Processing Record 32 of Set 10 | jamestown
# Processing Record 33 of Set 10 | acqui terme
# Processing Record 34 of Set 10 | robore
# Processing Record 35 of Set 10 | happy valley-goose bay
# Processing Record 36 of Set 10 | angaur state
# Processing Record 37 of Set 10 | al jawf
# Processing Record 38 of Set 10 | ta`u
# Processing Record 39 of Set 10 | saint-pierre
# Processing Record 40 of Set 10 | an nuhud
# Processing Record 41 of Set 10 | mariental
# Processing Record 42 of Set 10 | gaspe
# Processing Record 43 of Set 10 | mejit
# Processing Record 44 of Set 10 | sao joao da barra
# Processing Record 45 of Set 10 | tougan
# Processing Record 46 of Set 10 | tokar
# Processing Record 47 of Set 10 | santana
# Processing Record 48 of Set 10 | severo-yeniseyskiy
# Processing Record 49 of Set 10 | lata
# Processing Record 50 of Set 10 | mutuali
# Processing Record 1 of Set 11 | turbat
# Processing Record 2 of Set 11 | tak
# Processing Record 3 of Set 11 | balabac
# Processing Record 4 of Set 11 | san antonio de pale
# Processing Record 5 of Set 11 | vingt cinq
# City not found. Skipping...
# Processing Record 6 of Set 11 | lappeenranta
# Processing Record 7 of Set 11 | al 'alamayn
# City not found. Skipping...
# Processing Record 8 of Set 11 | manokwari
# Processing Record 9 of Set 11 | wuwei
# Processing Record 10 of Set 11 | athens
# Processing Record 11 of Set 11 | rodez
# Processing Record 12 of Set 11 | batken
# Processing Record 13 of Set 11 | kangding
# Processing Record 14 of Set 11 | jose maria morelos
# Processing Record 15 of Set 11 | kapa'a
# Processing Record 16 of Set 11 | fuente el saz
# Processing Record 17 of Set 11 | kupino
# Processing Record 18 of Set 11 | sao vicente
# Processing Record 19 of Set 11 | puerto leguizamo
# Processing Record 20 of Set 11 | diamantina
# Processing Record 21 of Set 11 | hilo
# Processing Record 22 of Set 11 | marco island
# Processing Record 23 of Set 11 | hastings
# Processing Record 24 of Set 11 | mount isa
# Processing Record 25 of Set 11 | xiaoweizhai
# Processing Record 26 of Set 11 | kayenta
# Processing Record 27 of Set 11 | thabazimbi
# Processing Record 28 of Set 11 | port saint john's
# Processing Record 29 of Set 11 | mahibadhoo
# Processing Record 30 of Set 11 | pechora
# Processing Record 31 of Set 11 | santo antonio do ica
# Processing Record 32 of Set 11 | loen
# Processing Record 33 of Set 11 | hadibu
# Processing Record 34 of Set 11 | weyburn
# Processing Record 35 of Set 11 | poddebice
# Processing Record 36 of Set 11 | markivka
# Processing Record 37 of Set 11 | vallenar
# Processing Record 38 of Set 11 | obo
# Processing Record 39 of Set 11 | moranha
# Processing Record 40 of Set 11 | ancud
# Processing Record 41 of Set 11 | kingscliff
# Processing Record 42 of Set 11 | alo
# Processing Record 43 of Set 11 | vorkuta
# Processing Record 44 of Set 11 | bismarck
# Processing Record 45 of Set 11 | butembo
# Processing Record 46 of Set 11 | sinabang
# Processing Record 47 of Set 11 | coppell
# Processing Record 48 of Set 11 | nuku'alofa
# Processing Record 49 of Set 11 | noumea
# Processing Record 50 of Set 11 | rosarito
# Processing Record 1 of Set 12 | petrovsk-zabaykal'skiy
# Processing Record 2 of Set 12 | youghal
# Processing Record 3 of Set 12 | jiuquan
# Processing Record 4 of Set 12 | chosica
# Processing Record 5 of Set 12 | maridi
# Processing Record 6 of Set 12 | artashat
# Processing Record 7 of Set 12 | kyren
# Processing Record 8 of Set 12 | puerto san carlos
# City not found. Skipping...
# Processing Record 9 of Set 12 | itaituba
# Processing Record 10 of Set 12 | alice springs
# Processing Record 11 of Set 12 | hovd
# Processing Record 12 of Set 12 | zeya
# Processing Record 13 of Set 12 | al jahra'
# Processing Record 14 of Set 12 | val-d'or
# Processing Record 15 of Set 12 | pontianak
# Processing Record 16 of Set 12 | kondoa
# Processing Record 17 of Set 12 | champoton
# Processing Record 18 of Set 12 | pemba
# Processing Record 19 of Set 12 | carauari
# Processing Record 20 of Set 12 | baoying
# Processing Record 21 of Set 12 | xining
# Processing Record 22 of Set 12 | salinopolis
# Processing Record 23 of Set 12 | arar
# Processing Record 24 of Set 12 | wynyard
# Processing Record 25 of Set 12 | kerikeri
# Processing Record 26 of Set 12 | sikasso
# Processing Record 27 of Set 12 | wewak
# Processing Record 28 of Set 12 | bechar
# Processing Record 29 of Set 12 | gamba
# Processing Record 30 of Set 12 | basna
# Processing Record 31 of Set 12 | scarborough
# Processing Record 32 of Set 12 | rancharia
# Processing Record 33 of Set 12 | gambiran satu
# Processing Record 34 of Set 12 | as samawah
# Processing Record 35 of Set 12 | bereeda
# Processing Record 36 of Set 12 | pachino
# Processing Record 37 of Set 12 | saveni
# Processing Record 38 of Set 12 | bayan nur
# City not found. Skipping...
# Processing Record 39 of Set 12 | selfoss
# Processing Record 40 of Set 12 | bloemfontein
# Processing Record 41 of Set 12 | raja
# Processing Record 42 of Set 12 | agat village
# Processing Record 43 of Set 12 | tamandare
# Processing Record 44 of Set 12 | helong
# Processing Record 45 of Set 12 | seogwipo
# City not found. Skipping...
# Processing Record 46 of Set 12 | arno
# Processing Record 47 of Set 12 | basco
# Processing Record 48 of Set 12 | revda
# Processing Record 49 of Set 12 | walvis bay
# Processing Record 50 of Set 12 | shenkursk
# Processing Record 1 of Set 13 | ubari
# Processing Record 2 of Set 13 | sumbawa besar
# Processing Record 3 of Set 13 | kapiri mposhi
# Processing Record 4 of Set 13 | gaigeturi
# Processing Record 5 of Set 13 | kyneton
# Processing Record 6 of Set 13 | shache
# Processing Record 7 of Set 13 | rechka-vydrino
# Processing Record 8 of Set 13 | bukan
# Processing Record 9 of Set 13 | ponta delgada
# Processing Record 10 of Set 13 | okhotsk
# Processing Record 11 of Set 13 | laojunmiao
# Processing Record 12 of Set 13 | island harbour
# Processing Record 13 of Set 13 | surgana
# Processing Record 14 of Set 13 | peel
# Processing Record 15 of Set 13 | quepos
# Processing Record 16 of Set 13 | san andres
# Processing Record 17 of Set 13 | chegdomyn
# Processing Record 18 of Set 13 | uniao da vitoria
# Processing Record 19 of Set 13 | kolonia
# Processing Record 20 of Set 13 | carutapera
# Processing Record 21 of Set 13 | chemolgan
# Processing Record 22 of Set 13 | imbituba
# Processing Record 23 of Set 13 | jinchang
# Processing Record 24 of Set 13 | port hedland
# Processing Record 25 of Set 13 | taltal
# Processing Record 26 of Set 13 | isiro
# Processing Record 27 of Set 13 | ba
# City not found. Skipping...
# Processing Record 28 of Set 13 | erriadh
# City not found. Skipping...
# Processing Record 29 of Set 13 | coahuayana de hidalgo
# Processing Record 30 of Set 13 | quatre cocos
# Processing Record 31 of Set 13 | neiafu
# Processing Record 32 of Set 13 | ibotirama
# Processing Record 33 of Set 13 | gaillard
# Processing Record 34 of Set 13 | belyy yar
# Processing Record 35 of Set 13 | laikit, laikit ii (dimembe)
# Processing Record 36 of Set 13 | udachny
# Processing Record 37 of Set 13 | shama junction
# Processing Record 38 of Set 13 | fisterra
# Processing Record 39 of Set 13 | arraial do cabo
# Processing Record 40 of Set 13 | acapulco de juarez
# Processing Record 41 of Set 13 | sao raimundo das mangabeiras
# Processing Record 42 of Set 13 | al kharj
# Processing Record 43 of Set 13 | smidovich
# Processing Record 44 of Set 13 | novofedorivka
# Processing Record 45 of Set 13 | san rafael
# Processing Record 46 of Set 13 | lerwick
# Processing Record 47 of Set 13 | mossel bay
# Processing Record 48 of Set 13 | laihia
# Processing Record 49 of Set 13 | undurkhaan
# Processing Record 50 of Set 13 | kananga
# Processing Record 1 of Set 14 | sabha
# Processing Record 2 of Set 14 | ciudad melchor muzquiz
# Processing Record 3 of Set 14 | dom pedrito
# Processing Record 4 of Set 14 | fort st. john
# Processing Record 5 of Set 14 | madanapalle
# Processing Record 6 of Set 14 | qamdo
# Processing Record 7 of Set 14 | northam
# Processing Record 8 of Set 14 | ridder
# Processing Record 9 of Set 14 | tumbes
# Processing Record 10 of Set 14 | ekibastuz
# Processing Record 11 of Set 14 | guerrero negro
# Processing Record 12 of Set 14 | inhambane
# Processing Record 13 of Set 14 | solwezi
# Processing Record 14 of Set 14 | kasongo-lunda
# Processing Record 15 of Set 14 | vuktyl
# Processing Record 16 of Set 14 | champerico
# Processing Record 17 of Set 14 | mtwara
# Processing Record 18 of Set 14 | launceston
# Processing Record 19 of Set 14 | livadiya
# Processing Record 20 of Set 14 | jerantut
# Processing Record 21 of Set 14 | vila do maio
# Processing Record 22 of Set 14 | gallipoli
# Processing Record 23 of Set 14 | sainte-anne-de-bellevue
# Processing Record 24 of Set 14 | palmaner
# Processing Record 25 of Set 14 | bulawayo
# Processing Record 26 of Set 14 | colares
# Processing Record 27 of Set 14 | weno
# Processing Record 28 of Set 14 | foumbot
# Processing Record 29 of Set 14 | duayaw-nkwanta
# Processing Record 30 of Set 14 | sassandra
# Processing Record 31 of Set 14 | heroica caborca
# Processing Record 32 of Set 14 | kilindoni
# Processing Record 33 of Set 14 | shingu
# Processing Record 34 of Set 14 | hukumati azrah
# Processing Record 35 of Set 14 | kalmunai
# Processing Record 36 of Set 14 | bhimunipatnam
# Processing Record 37 of Set 14 | great falls
# Processing Record 38 of Set 14 | mili
# Processing Record 39 of Set 14 | anacapri
# Processing Record 40 of Set 14 | elliot
# Processing Record 41 of Set 14 | winejok
# City not found. Skipping...
# Processing Record 42 of Set 14 | cloverdale
# Processing Record 43 of Set 14 | iquitos
# Processing Record 44 of Set 14 | surgut
# Processing Record 45 of Set 14 | lethem
# Processing Record 46 of Set 14 | kaffrine
# Processing Record 47 of Set 14 | saudarkrokur
# Processing Record 48 of Set 14 | fortuna
# Processing Record 49 of Set 14 | cherkessk
# Processing Record 50 of Set 14 | strezhevoy
# Processing Record 1 of Set 15 | salahonda
# Processing Record 2 of Set 15 | isle of bute
# City not found. Skipping...
# Processing Record 3 of Set 15 | mlowo
# Processing Record 4 of Set 15 | ulsteinvik
# Processing Record 5 of Set 15 | tabarka
# Processing Record 6 of Set 15 | mil'kovo
# Processing Record 7 of Set 15 | floriano
# Processing Record 8 of Set 15 | puerto lempira
# Processing Record 9 of Set 15 | oppdal
# Processing Record 10 of Set 15 | shalqar
# Processing Record 11 of Set 15 | arboga
# Processing Record 12 of Set 15 | eraan
# Processing Record 13 of Set 15 | tra mhor
# Processing Record 14 of Set 15 | saint john
# Processing Record 15 of Set 15 | anse la raye
# Processing Record 16 of Set 15 | nur-sultan
# Processing Record 17 of Set 15 | praya
# Processing Record 18 of Set 15 | sabzevar
# Processing Record 19 of Set 15 | emerald
# Processing Record 20 of Set 15 | serdar
# Processing Record 21 of Set 15 | minot air force base
# Processing Record 22 of Set 15 | kupang
# Processing Record 23 of Set 15 | nagato
# Processing Record 24 of Set 15 | las palmas
# Processing Record 25 of Set 15 | ouadda
# Processing Record 26 of Set 15 | pasighat
# Processing Record 27 of Set 15 | pauini
# Processing Record 28 of Set 15 | salalah
# Processing Record 29 of Set 15 | ruelle-sur-touvre
# Processing Record 30 of Set 15 | okha
# Processing Record 31 of Set 15 | ebon
# Processing Record 32 of Set 15 | sonqor
# Processing Record 33 of Set 15 | diu
# Processing Record 34 of Set 15 | lundazi
# Processing Record 35 of Set 15 | bowen
# Processing Record 36 of Set 15 | palo santo
# Processing Record 37 of Set 15 | hoxtolgay
# City not found. Skipping...
# Processing Record 38 of Set 15 | nema
# Processing Record 39 of Set 15 | sur
# Processing Record 40 of Set 15 | nova vicosa
# Processing Record 41 of Set 15 | xilin hot
# Processing Record 42 of Set 15 | mary
# Processing Record 43 of Set 15 | kenora
# Processing Record 44 of Set 15 | mamuju
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Print the length of the city_data list to verify how many cities you have
len(city_data)
# Out:
# 710

# %% [markdown]
# ## Add the weather data to a new DataFrame.

# %%
# Use the city_data list to create a new pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df=city_data_df.rename(columns={"Desc": "Current Description"})

# %%
# Display sample data
city_data_df.head(10)
# Out:
#                 City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0           Qaqortoq  60.7167  -46.0333     37.26        70         100
# 1          Grytviken -54.2811  -36.5092     30.13        79          18
# 2      Blackmans Bay -43.0167  147.3167     54.73        74         100
# 3               Voss  60.6230    6.4229     46.54        99         100
# 4              Nadym  65.5333   72.5167     56.37        86         100
# 5           Bilibino  68.0546  166.4372     42.71        63         100
# 6             Badger  64.8000 -147.5333     68.50        29          40
# 7  Wailua Homesteads  22.0669 -159.3780     79.86        72          20
# 8          Carbonear  47.7332  -53.2148     46.15        82         100
# 9           Jayapura  -2.5333  140.7000     72.79        89         100
#
#    Wind Speed Country Current Description
# 0        0.40      GL     overcast clouds
# 1       12.93      GS          few clouds
# 2        1.50      AU     overcast clouds
# 3        7.07      NO     overcast clouds
# 4       18.48      RU     overcast clouds
# 5       18.66      RU     overcast clouds
# 6       12.66      US    scattered clouds
# 7       12.66      US          light rain
# 8       11.36      CA     overcast clouds
# 9        4.92      ID     overcast clouds

# %%
# Display the DataFrame's column names using the columns Pandas function
city_data_df.columns
# Out:
# Index(['City', 'Lat', 'Lng', 'Max Temp', 'Humidity', 'Cloudiness',
#        'Wind Speed', 'Country', 'Current Description'],
#       dtype='object')

# %%
# Create a list to reorder the column names as follows:
# "City", "Country", "Lat", "Lng", "Max Temp", "Humidity",  "Cloudiness", "Wind Speed",  "Current Description"
new_column_order = ["City", "Country", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed","Current Description"]

# Recreate the DataFrame by using the new column order
city_data_df = city_data_df[new_column_order]

# Display sample data
city_data_df.head()
# Out:
#             City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0       Qaqortoq      GL  60.7167  -46.0333     37.26        70         100
# 1      Grytviken      GS -54.2811  -36.5092     30.13        79          18
# 2  Blackmans Bay      AU -43.0167  147.3167     54.73        74         100
# 3           Voss      NO  60.6230    6.4229     46.54        99         100
# 4          Nadym      RU  65.5333   72.5167     56.37        86         100
#
#    Wind Speed Current Description
# 0        0.40     overcast clouds
# 1       12.93          few clouds
# 2        1.50     overcast clouds
# 3        7.07     overcast clouds
# 4       18.48     overcast clouds

# %%
# Display the data types of each column by using the dtypes Pandas function
city_data_df.dtypes
# Out:
# City                    object
# Country                 object
# Lat                    float64
# Lng                    float64
# Max Temp               float64
# Humidity                 int64
# Cloudiness               int64
# Wind Speed             float64
# Current Description     object
# dtype: object

# %% [markdown]
# ## Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.

# %%
# Set the output file name
output_data_file = "WeatherPy_Database.csv"

# Export the city_data DataFrame into a CSV file
city_data_df.to_csv(output_data_file, index_label="City_ID")
